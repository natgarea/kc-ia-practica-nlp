# %% [markdown]
# # Práctica NLP
#
# Este trabajo presenta un sistema de clasificación binaria de sentimientos aplicado a reviews de libros de Amazon. El objetivo es predecir si una review es positiva o negativa basándose en el texto escrito por los usuarios.

# %% [markdown]
# ## 2. Preprocesado del texto

# %%
import pandas as pd
import pickle

# Importar datos del notebook anterior
with open('data_para_ejecutar_ejercicio2.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
# !pip install spacy==3.7.2

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# Cargar modelo de inglés
nlp = spacy.load('en_core_web_sm')

def preprocess_review(text):
    """ Preprocesa una review """

    # Comprueba que hay texto
    if not text or text != text:
        return ""

    # Convierte a minúsculas
    doc = nlp(text.lower())

    # Tokens procesados
    processed_tokens = []

    for token in doc:
        # Dejar tokens alfabéticos, no stopwords, no puntuación
        if token.is_alpha and token.text not in STOP_WORDS:
            processed_tokens.append(token.lemma_)

    return ' '.join(processed_tokens)

df['processed_review'] = df['review'].apply(preprocess_review)
# Out:
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
print("Original:", df['review'].iloc[0][:200])
print("\nProcesada:", df['processed_review'].iloc[0][:200])
# Out:
# Original: Formulaic MacLean story.  Starts with Amsterdam airoport flooded, as a way of getting the readers' attention, moves to further floods (dikes blasted) in the Netherlands and threats of even more, as a
#
# Procesada: formulaic maclean story start amsterdam airoport flood way get reader attention move flood dike blast netherlands threat way draw attention terrorist demand hero typical maclean hero little good fluen

# %%
# Guardar datos para el siguiente notebook
with open('data_para_ejecutar_ejercicio3.pkl', 'wb') as f:
    pickle.dump(df, f)
